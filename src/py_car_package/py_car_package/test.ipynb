# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t1 = np.load("lane1.npy")
print(t1.shape)
# Out:
# (1277, 3)

# %%
x = t1[:, 1]
y = t1[:, 2]
print(y.shape)
arc = t1[:, 0]
print(arc.shape)
# Out:
# (1277,)
# (1277,)

# %%
plt.plot(x, y)
plt.scatter(arc, x)

# %%
print(arc)
# Out:
# [0.00000000e+00 1.00000000e-02 2.00000000e-02 ... 1.27382348e+01
#  1.27482347e+01 1.27582347e+01]
